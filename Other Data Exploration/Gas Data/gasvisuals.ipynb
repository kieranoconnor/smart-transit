# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./GasPrices.csv")
display(df)
# Out:
#             date  price
# 0     10/24/2022  5.604
# 1     10/17/2022  5.940
# 2     10/10/2022  6.251
# 3      10/3/2022  6.315
# 4     09/26/2022  5.721
# ...          ...    ...
# 1166  06/19/2000  1.664
# 1167  06/12/2000  1.662
# 1168   06/5/2000  1.661
# 1169  05/29/2000  1.673
# 1170  05/22/2000  1.679
#
# [1171 rows x 2 columns]

# %%
gps = pd.read_csv('gpsdata.csv')
gps.head().T
# Out:
#                                                    0  \
# SERIAL_NUMBER                                7321967
# SCHEDULE_ID                                      425
# SCHEDULE_NAME                        20Jan (Weekday)
# SIGNUP_NAME                               Prod-Jan20
# SURVEY_DATE                                 2/3/2020
# PATTERN_ID                                 191200145
# ROUTE_NUMBER                                      77
# ROUTE_NAME           77: Eastridge - Great Mall/Main
# DIRECTION_NAME                                 NORTH
# BRANCH                 [77]Eastridge - Milpitas BART
# SERVICE_CODE                                    Core
# SERVICE_MODE                                     Bus
# TRIP_START_TIME                              8:24:00
# TIME_PERIOD                                  AM Peak
# SERVICE_PERIOD                               Weekday
# TRIP_NUMBER                                       26
# TRIP_KEY                                     2452267
# ...

# %%
pass_per_block_day = gps.groupby(['BLOCK_NAME', 'SURVEY_DATE'])['PASSENGERS_IN'].sum()

pass_per_block_day.head()
# Out:
# BLOCK_NAME  SURVEY_DATE
# 2601        2/16/2020      260
#             2/2/2020       202
# 2602        2/11/2020       70
#             2/12/2020       28
#             2/13/2020      207
# Name: PASSENGERS_IN, dtype: int64

# %%
gps.BLOCK_NAME.value_counts()
gps[gps['BLOCK_NAME'] >= 7100].BLOCK_NAME.value_counts()
# Out:
# 7771    9166
# 7773    7318
# 7774    6558
# 7702    4296
# 7772    4001
# 7701    3870
# 7703    3467
# 7775    2270
# 7171    1824
# 7075    1260
# 7073     849
# 7776     841
# 7001     802
# 7002     696
# 7003     630
# 7173     630
# 7071     564
# 7074     450
# 7176     423
# Name: BLOCK_NAME, dtype: int64
