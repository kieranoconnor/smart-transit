# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Regen Rate while Driving
df = pd.read_csv("./RegenvsKWH.csv")
display(df)
# Out:
#                DateTime  2600 - Regeneration rate  2601 - Regeneration rate  \
# 0   2022-10-06 00:00:00                       NaN                       NaN
# 1   2022-10-07 00:00:00                       NaN                       NaN
# 2   2022-10-10 00:00:00                       NaN                       NaN
# 3   2022-10-11 00:00:00                       NaN                       NaN
# 4   2022-10-12 00:00:00                       NaN                       NaN
# 5   2022-10-13 00:00:00                       NaN                       NaN
# 6   2022-10-14 00:00:00                       NaN                       NaN
# 7   2022-10-17 00:00:00                       NaN                       NaN
# 8   2022-10-18 00:00:00                       NaN                       NaN
# 9   2022-10-19 00:00:00                       NaN                       NaN
# 10  2022-10-20 00:00:00                       NaN                       NaN
# ...

# %%
average = df.mean()
average
# Out:
# C:\Users\garre\AppData\Local\Temp\ipykernel_2788\1850525536.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   average = df.mean()
# 2600 - Regeneration rate          NaN
# 2601 - Regeneration rate    26.671072
# 2602 - Regeneration rate    26.779317
# 2603 - Regeneration rate    26.906531
# 2604 - Regeneration rate          NaN
# 2605 - Regeneration rate    23.114049
# 2606 - Regeneration rate    29.549487
# 2607 - Regeneration rate    31.296234
# 2608 - Regeneration rate    25.867507
# 2609 - Regeneration rate    29.486533
# 2610 - Regeneration rate    28.671430
# 2611 - Regeneration rate    30.657267
# 2612 - Regeneration rate    31.432347
# 2613 - Regeneration rate    29.793775
# dtype: float64

# %%
# KWH/Mi
df2 = pd.read_csv("./KWHforRegen.csv")
display(df2)
# Out:
#                DateTime  2600 - Consumption driving  \
# 0   2022-10-06 00:00:00                         NaN
# 1   2022-10-07 00:00:00                         NaN
# 2   2022-10-10 00:00:00                         NaN
# 3   2022-10-11 00:00:00                         NaN
# 4   2022-10-12 00:00:00                         NaN
# 5   2022-10-13 00:00:00                         NaN
# 6   2022-10-14 00:00:00                         NaN
# 7   2022-10-17 00:00:00                         NaN
# 8   2022-10-18 00:00:00                         NaN
# 9   2022-10-19 00:00:00                         NaN
# 10  2022-10-20 00:00:00                         NaN
# 11  2022-10-21 00:00:00                         NaN
# 12  2022-10-24 00:00:00                         NaN
# 13  2022-10-25 00:00:00                         NaN
# 14  2022-10-26 00:00:00                         NaN
# 15  2022-10-27 00:00:00                         NaN
# 16  2022-10-28 00:00:00                         NaN
# ...

# %%
averageKWH = df2.mean()
averageKWH
# Out:
# C:\Users\garre\AppData\Local\Temp\ipykernel_2788\1629123068.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   averageKWH = df2.mean()
# 2600 - Consumption driving         NaN
# 2601 - Consumption driving    1.599164
# 2602 - Consumption driving    1.521887
# 2603 - Consumption driving    1.679573
# 2604 - Consumption driving         NaN
# 2605 - Consumption driving    1.917846
# 2606 - Consumption driving    1.587821
# 2607 - Consumption driving    1.394295
# 2608 - Consumption driving    1.616602
# 2609 - Consumption driving    1.558970
# 2610 - Consumption driving    1.281961
# 2611 - Consumption driving    1.540390
# 2612 - Consumption driving    1.623602
# 2613 - Consumption driving    1.634474
# dtype: float64

# %%
dataFrame = {'Regen':average, 'KWH':averageKWH}
df3 = pd.DataFrame(dataFrame)
df3
# Out:
#                                 Regen       KWH
# 2600 - Consumption driving        NaN       NaN
# 2600 - Regeneration rate          NaN       NaN
# 2601 - Consumption driving        NaN  1.599164
# 2601 - Regeneration rate    26.671072       NaN
# 2602 - Consumption driving        NaN  1.521887
# 2602 - Regeneration rate    26.779317       NaN
# 2603 - Consumption driving        NaN  1.679573
# 2603 - Regeneration rate    26.906531       NaN
# 2604 - Consumption driving        NaN       NaN
# 2604 - Regeneration rate          NaN       NaN
# 2605 - Consumption driving        NaN  1.917846
# 2605 - Regeneration rate    23.114049       NaN
# 2606 - Consumption driving        NaN  1.587821
# 2606 - Regeneration rate    29.549487       NaN
# 2607 - Consumption driving        NaN  1.394295
# 2607 - Regeneration rate    31.296234       NaN
# 2608 - Consumption driving        NaN  1.616602
# 2608 - Regeneration rate    25.867507       NaN
# 2609 - Consumption driving        NaN  1.558970
# ...

# %%
read = pd.read_csv("./RegenKWH.csv")
display(read)
# Out:
#      Bus      Regen       KWH
# 0   2601  26.671072  1.599164
# 1   2602  26.779317  1.521887
# 2   2603  26.906531  1.679573
# 3   2605  23.114049  1.917846
# 4   2606  29.549487  1.587821
# 5   2607  31.296234  1.394295
# 6   2608  25.867507  1.616602
# 7   2609  29.486533  1.558970
# 8   2610  28.671430  1.281961
# 9   2611  30.657267  1.540390
# 10  2612  31.432347  1.623602
# 11  2613  29.793775  1.634474

# %%
# KWH vs Regen Driving over a month
sns.scatterplot(x='Regen', y='KWH', data=read)
# Out:
# <AxesSubplot: xlabel='Regen', ylabel='KWH'>
