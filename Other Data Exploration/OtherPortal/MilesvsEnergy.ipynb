# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./MilesvsEnergy.csv")
df.columns = ['DateTime', 'TotalMiles', 'EnergyConsumed']
display(df)
# Out:
#                 DateTime    TotalMiles  EnergyConsumed
# 0    2019-04-26 00:00:00   8332.988472        1.907360
# 1    2019-04-29 00:00:00   8415.550063      197.861110
# 2    2019-05-01 00:00:00   8716.539583      230.526656
# 3    2019-05-02 00:00:00   8867.364591      336.790718
# 4    2019-05-03 00:00:00   9023.797895      390.366647
# ..                   ...           ...             ...
# 534  2020-12-23 00:00:00  80310.378017      467.824881
# 535  2020-12-24 00:00:00  80505.600419      468.265099
# 536  2020-12-28 00:00:00  80732.264202      545.652840
# 537  2020-12-29 00:00:00  80934.861385      510.470691
# 538  2020-12-30 00:00:00  81164.983157      536.592451
#
# [539 rows x 3 columns]

# %%
sns.scatterplot(x='EnergyConsumed', y='TotalMiles', data=df)
# Out:
# <AxesSubplot: xlabel='EnergyConsumed', ylabel='TotalMiles'>

# %%
df.EnergyConsumed.corr(df.TotalMiles)
# Out:
# 0.12058567548744716

# %%
df2 = pd.read_csv("./EnergyvsMiles.csv")
df2.columns = ['DateTime', 'EnergyConsumed', 'MilesDriven']
display(df2)
# Out:
#                 DateTime  EnergyConsumed  MilesDriven
# 0    2019-04-26 00:00:00        1.907360     0.717684
# 1    2019-04-29 00:00:00      197.861110    82.514987
# 2    2019-05-01 00:00:00      230.526656    94.396026
# 3    2019-05-02 00:00:00      336.790718   150.128049
# 4    2019-05-03 00:00:00      390.366647   156.431221
# ..                   ...             ...          ...
# 534  2020-12-23 00:00:00      467.824881   194.186896
# 535  2020-12-24 00:00:00      468.265099   195.154973
# 536  2020-12-28 00:00:00      545.652840   226.626501
# 537  2020-12-29 00:00:00      510.470691   202.556793
# 538  2020-12-30 00:00:00      536.592451   230.090704
#
# [539 rows x 3 columns]

# %%
sns.scatterplot(x='EnergyConsumed', y='MilesDriven', data=df2)
# Out:
# <AxesSubplot: xlabel='EnergyConsumed', ylabel='MilesDriven'>
